# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Liver_df = pd.read_csv('Liver_disease_DupDataset.csv')
Liver_df
# Out:
#       Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0      65  Female              0.7               0.1                   187
# 1      62    Male             10.9               5.5                   699
# 2      62    Male              7.3               4.1                   490
# 3      58    Male              1.0               0.4                   182
# 4      72    Male              3.9               2.0                   195
# ...   ...     ...              ...               ...                   ...
# 1744   60    Male              0.5               0.1                   500
# 1745   40    Male              0.6               0.1                    98
# 1746   52    Male              0.8               0.2                   245
# 1747   31    Male              1.3               0.5                   184
# 1748   38    Male              1.0               0.3                   216
#
# ...

# %%
print(Liver_df.describe())
# print(Liver_DataFrame.info())
# Out:
#                Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  1749.000000      1749.000000       1749.000000           1749.000000
# mean     44.746141         3.298799          1.486106            290.576329
# std      16.180569         6.205968          2.806890            242.798969
# min       4.000000         0.400000          0.100000             63.000000
# 25%      33.000000         0.800000          0.200000            175.000000
# 50%      45.000000         1.000000          0.300000            208.000000
# 75%      58.000000         2.600000          1.300000            298.000000
# max      90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count               1749.000000                 1749.000000      1749.00000
# mean                  80.713551                  109.910806         6.48319
# ...

# %%
Liver_df.isnull().sum()
# Out:
# Age                            0
# Gender                         0
# Total_Bilirubin                0
# Direct_Bilirubin               0
# Alkaline_Phosphotase           0
# Alamine_Aminotransferase       0
# Aspartate_Aminotransferase     0
# Total_Protiens                 0
# Albumin                        0
# Albumin_and_Globulin_Ratio    12
# Dataset                        0
# dtype: int64

# %%
Liver_df.Albumin_and_Globulin_Ratio = Liver_df.Albumin_and_Globulin_Ratio.fillna(Liver_df["Albumin_and_Globulin_Ratio"].mean())
Liver_df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
L = LabelEncoder()
Liver_df["Gender"] = L.fit_transform(Liver_df["Gender"])
Liver_df["Gender"].head(15)
# Out:
# 0     0
# 1     1
# 2     1
# 3     1
# 4     1
# 5     1
# 6     0
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    1
# 13    0
# 14    1
# Name: Gender, dtype: int32

# %%
Liver_df['Age'] = Liver_df['Age']/Liver_df['Age'].max()
Liver_df['Total_Bilirubin'] = Liver_df['Total_Bilirubin']/Liver_df['Total_Bilirubin'].max()
Liver_df['Direct_Bilirubin'] = Liver_df['Direct_Bilirubin']/Liver_df['Direct_Bilirubin'].max()
Liver_df['Alkaline_Phosphotase'] = Liver_df['Alkaline_Phosphotase']/Liver_df['Alkaline_Phosphotase'].max()
Liver_df['Aspartate_Aminotransferase'] = Liver_df['Aspartate_Aminotransferase']/Liver_df['Aspartate_Aminotransferase'].max()
Liver_df['Albumin'] = Liver_df['Albumin']/Liver_df['Albumin'].max()
Liver_df['Albumin_and_Globulin_Ratio'] = Liver_df['Albumin_and_Globulin_Ratio']/Liver_df['Albumin_and_Globulin_Ratio'].max()
Liver_df.head()
# Out:
#         Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0  0.722222       0         0.009333          0.005076              0.088626
# 1  0.688889       1         0.145333          0.279188              0.331280
# 2  0.688889       1         0.097333          0.208122              0.232227
# 3  0.644444       1         0.013333          0.020305              0.086256
# 4  0.800000       1         0.052000          0.101523              0.092417
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                    0.003652             6.8
# 1                        64                    0.020288             7.5
# 2                        60                    0.013796             7.0
# 3                        14                    0.004058             6.8
# 4                        27                    0.011970             7.3
#
#     Albumin  Albumin_and_Globulin_Ratio  Dataset
# ...

# %%
X=Liver_df.drop(["Dataset","Total_Bilirubin","Alamine_Aminotransferase","Total_Protiens"], axis=1)
y=Liver_df["Dataset"]
print(X.shape, y.shape)
X.describe()
# Out:
# (1749, 7) (1749,)
#                Age       Gender  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  1749.000000  1749.000000       1749.000000           1749.000000
# mean      0.497179     0.756432          0.075437              0.137714
# std       0.179784     0.429358          0.142482              0.115071
# min       0.044444     0.000000          0.005076              0.029858
# 25%       0.366667     1.000000          0.010152              0.082938
# 50%       0.500000     1.000000          0.015228              0.098578
# 75%       0.644444     1.000000          0.065990              0.141232
# max       1.000000     1.000000          1.000000              1.000000
#
#        Aspartate_Aminotransferase      Albumin  Albumin_and_Globulin_Ratio
# count                 1749.000000  1749.000000                 1749.000000
# mean                     0.022299     0.571246                    0.338237
# std                      0.058583     0.144557                    0.113682
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=1)
print(len(X_train),len(X_test))
# Out:
# 1399 350

# %%
X_train.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Aspartate_Aminotransferase    0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# dtype: int64

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
param_dist ={
    "criterion":['gini', 'entropy', 'log_loss'],
    "max_depth":[1,2,3,4,5,6,None],
    "max_features": ['auto', 'sqrt', 'log2'],
    "splitter":['best', 'random']
}

from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(model, param_grid=param_dist, cv=10, n_jobs=-1)
grid.fit(X_train,y_train)
# Out:
# C:\Users\babun\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 420 fits failed out of a total of 1260.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 206 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\babun\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\babun\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
# ...

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'splitter': 'random'}
# 0.980688591983556

# %%
from sklearn import tree
mdl = tree.DecisionTreeClassifier(criterion="gini",max_depth=3, max_features="log2", splitter="random")
mdl.fit(X_train,y_train)
mdl.score(X_test,y_test)*100 # after tuning 71
# Out:
# 72.0
