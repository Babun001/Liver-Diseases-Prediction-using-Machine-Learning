# %%
# ipynb full form is Interactive Python Notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27f5ab71a10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27f5ab72d50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27f5ab71250>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x27f5ab73e10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x27f5ab84690>,
# ...
#  'means': []}
